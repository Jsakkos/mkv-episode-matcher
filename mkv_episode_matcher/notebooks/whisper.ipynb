# %%
import whisper
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import whisper
#       2 import os
#
# File c:\Users\Jonathan\anaconda3\envs\whisper\Lib\site-packages\whisper\__init__.py:8
#       5 import warnings
#       6 from typing import List, Optional, Union
# ----> 8 import torch
#       9 from tqdm import tqdm
#      11 from .audio import load_audio, log_mel_spectrogram, pad_or_trim
#
# File c:\Users\Jonathan\anaconda3\envs\whisper\Lib\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "c:\Users\Jonathan\anaconda3\envs\whisper\Lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.

# %%
import torch

if torch.cuda.is_available():
    print(f"CUDA is available. Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. Using CPU.")

# It will print out the GPU that you are using.
# Out:
# Running cells with 'MKV-GPU (Python 3.8.10)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n MKV-GPU ipykernel --update-deps --force-reinstall'

# %%
model = whisper.load_model("base")  # Replace "base" with the desired model size
result = model.transcribe(r"C:\Users\Jonathan\output_audio.wav")

# Print or save the transcription
print(result["text"])
# Out:
# Running cells with 'MKV-GPU (Python 3.8.10)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n MKV-GPU ipykernel --update-deps --force-reinstall'

# %%
# ffmpeg -i "E:\Video\Seinfeld\Season 5\Seinfeld - Season 5 (Disc 1)-A1_t02.mkv" -t 300 -map 0:a:0 -acodec pcm_s16le -ac 1 output_audio.wav
# works for make a .wav file of the first 5 mins
# Out:
# Running cells with 'MKV-GPU (Python 3.8.10)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n MKV-GPU ipykernel --update-deps --force-reinstall'
